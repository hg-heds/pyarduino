# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np 
import matplotlib.pyplot as plt 
from scipy.optimize import curve_fit

# %%
dados = '''
86200 23
79600 24
67200 27
57250 29
52140 32
47430 34
39300 39
36920 41
33700 44
27350 50
23730 55
21310 58
17200 65
14820 70
12870 73
11730 78
10070 83
9450 85
8500 89
7090 95
6230 99
5486 104
4739 109
4387 112
3958 115
3544 118
3121 120
2919 124
2706 128
2429 131
2213 135
2014 138
1864 140
1751 142
1565 146
1500 148
1449 150
'''

# %%
dados = dados.split('\n')
dados = dados[1:-1]

# %%
res = []
temp = []
for aa in dados:
    res.append(int(aa.split(' ')[0]))
    temp.append(int(aa.split(' ')[1]))
temp = np.array([temp]).T
res = np.array([res]).T

# %%
plt.scatter(temp,res)

# %%
res_linear = np.log(res)
plt.plot(temp,res_linear,'r.')
plt.rcParams["figure.figsize"] = (20,20)

# %%
# Regression
regressor = LinearRegression()
results = regressor.fit(temp, res_linear)                # 2
model = results.predict
res_fit = model(temp)

# %%
plt.plot(temp,res_linear,'ro',temp,res_fit,'g-')

# %%
plt.scatter(temp, res)
plt.plot(temp, np.exp(res_fit), "k-", label="Fit")
plt.title("Exponential Fit")
# Out:
# Text(0.5, 1.0, 'Exponential Fit')

# %%
A = regressor.coef_[0,0]
B = regressor.intercept_[0]

# %%
Temp = np.linspace(20,145,60)
Res_linear = A * Temp + B
Res = np.exp(Res_linear)

# %%
plt.plot(Temp,Res_linear)

# %%
plt.plot(Temp,Res)

# %%
A
# Out:
# -0.030954630573987844

# %%
B
# Out:
# 11.835937807179443
